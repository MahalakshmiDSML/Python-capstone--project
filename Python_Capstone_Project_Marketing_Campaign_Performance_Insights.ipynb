# %% [markdown]
# <a href="https://colab.research.google.com/github/MahalakshmiDSML/Python-capstone--project/blob/main/Python_Capstone_Project_Marketing_Campaign_Performance_Insights.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Project Title: Marketing Campaign Performance Insights**

# %% [markdown]
# ##**Project Steps and Objectives:**
#
# ###**1) Load the Dataset**

# %% [markdown]
# ***Read the marketing campaign data from the CSV file into a pandas DataFrame.***

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

m_data=pd.read_csv("/content/Marketing Campaign Performance Details.txt")

# %% [markdown]
# ##**2) Descriptive Analysis**
# ###**Basic Structure:**
# **➢ Print the first few rows of the dataset to get an overview of the data.**

# %%
m_data.head()     # Show first Five Rows.
# Out:
#    Campaign_ID              Company Campaign_Type Target_Audience Duration  \
# 0            1             TechCorp         Email     Women 25-34  30 days
# 1            2  Innovate Industries    Influencer     Women 35-44  45 days
# 2            3       NexGen Systems  Social Media     Women 25-34  45 days
# 3            4  Innovate Industries         Email     Women 25-34  45 days
# 4            5  Data Tech Solutions    Influencer       Men 25-34  30 days
#
#   Channel_Used  Conversion_Rate  Acquisition_Cost     ROI          Location  \
# 0     Facebook         5.294194              9344   62.94           Houston
# 1   Google Ads         3.326375              8783   10.67  Washington, D.C.
# 2    Instagram         4.056375              9111   73.20             Miami
# 3    Instagram         4.496375              7420   60.92           Seattle
# 4   Google Ads         4.405930              2146  138.82           Chicago
#
# ...

# %% [markdown]
# **➢ Obtain the number of rows and columns in the dataset.**

# %%
m_data.shape   # Show total no of Rows & Columns.
# Out:
# (22029, 16)

# %% [markdown]
# **➢ Get a concise summary of the dataset, including the data types and non-null values.**

# %%
m_data.info()         # Show Data types & Non-null values.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22029 entries, 0 to 22028
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Campaign_ID       22029 non-null  int64
#  1   Company           22029 non-null  object
#  2   Campaign_Type     22029 non-null  object
#  3   Target_Audience   22029 non-null  object
#  4   Duration          22029 non-null  object
#  5   Channel_Used      22029 non-null  object
#  6   Conversion_Rate   22029 non-null  float64
#  7   Acquisition_Cost  22029 non-null  int64
#  8   ROI               22029 non-null  float64
#  9   Location          22029 non-null  object
#  10  Language          22029 non-null  object
#  11  Clicks            22029 non-null  int64
#  12  Impressions       22029 non-null  int64
#  13  Engagement_Score  22029 non-null  int64
#  14  Customer_Segment  22029 non-null  object
#  15  Date              22029 non-null  object
# ...

# %% [markdown]
# **➢ Generate descriptive statistics for numerical columns.**

# %%
m_data.describe()    # Show Numerical columns Count,Mean,Min,Max .
# Out:
#         Campaign_ID  Conversion_Rate  Acquisition_Cost           ROI  \
# count  22029.000000     22029.000000      22029.000000  22029.000000
# mean   11015.000000         4.757232       5522.740842    182.863648
# std     6359.368876         0.960393       2597.666260    301.619721
# min        1.000000         2.015723       1000.000000    -98.300000
# 25%     5508.000000         4.130705       3286.000000     -4.080000
# 50%    11015.000000         4.761527       5525.000000     93.650000
# 75%    16522.000000         5.429335       7766.000000    247.310000
# max    22029.000000         7.469907       9999.000000   3109.790000
#
#              Clicks   Impressions  Engagement_Score
# count  22029.000000  22029.000000      22029.000000
# mean    2223.807572  50610.402787          6.582323
# std     1394.166380  28542.979123          1.458804
# min       30.000000   1001.000000          4.000000
# 25%     1067.000000  25804.000000          5.000000
# ...

# %% [markdown]
# ##**Data Exploration:**
# **➢ Print the number of unique Campaign_ID values in the dataset.**

# %%
m_data["Campaign_ID"].unique()             # show Unique Campaign_ID.
print(m_data["Campaign_ID"].unique())
# Out:
# [    1     2     3 ... 22027 22028 22029]

# %%
m_data["Campaign_ID"].nunique()
# Out:
# 22029

# %% [markdown]
# **➢ List the unique values of the Location and Customer_Segment columns.**

# %%
m_data["Location"].unique()
# Out:
# array(['Houston', 'Washington, D.C.', 'Miami', 'Seattle', 'Chicago',
#        'Los Angeles', 'Atlanta', 'Dallas', 'New York', 'San Francisco'],
#       dtype=object)

# %%
m_data["Location"].nunique()    # Show total Unique value count
# Out:
# 10

# %%
m_data["Location"].value_counts()  # Show Each unique value count.
# Out:
# Location
# Houston             2317
# Los Angeles         2269
# Chicago             2247
# Seattle             2238
# Miami               2235
# Dallas              2176
# Washington, D.C.    2157
# San Francisco       2156
# New York            2146
# Atlanta             2088
# Name: count, dtype: int64

# %%
m_data['Customer_Segment'].unique()
# Out:
# array(['Tech Enthusiasts', 'Foodies', 'Fashionistas',
#        'Outdoor Adventurers', 'Health & Wellness'], dtype=object)

# %%
m_data["Customer_Segment"].nunique()
# Out:
# 5

# %%
m_data["Customer_Segment"].value_counts()
# Out:
# Customer_Segment
# Fashionistas           4504
# Outdoor Adventurers    4412
# Tech Enthusiasts       4393
# Foodies                4361
# Health & Wellness      4359
# Name: count, dtype: int64

# %% [markdown]
# **➢ Count the occurrences of each category in the Campaign_Type and**
# **Channel_Used and columns.**

# %%
m_data['Campaign_Type'].unique()
# Out:
# array(['Email', 'Influencer', 'Social Media', 'Display', 'Search'],
#       dtype=object)

# %%
m_data['Campaign_Type'].nunique()
# Out:
# 5

# %%
m_data['Campaign_Type'].value_counts()
# Out:
# Campaign_Type
# Display         4450
# Search          4441
# Social Media    4412
# Email           4388
# Influencer      4338
# Name: count, dtype: int64

# %%
m_data['Channel_Used'].unique()
# Out:
# array(['Facebook', 'Google Ads', 'Instagram', 'Website', 'Email',
#        'YouTube'], dtype=object)

# %%
m_data['Channel_Used'].nunique()
# Out:
# 6

# %%
m_data['Channel_Used'].value_counts()
# Out:
# Channel_Used
# Facebook      3742
# Google Ads    3694
# Website       3688
# Instagram     3649
# YouTube       3632
# Email         3624
# Name: count, dtype: int64

# %% [markdown]
# ##**3) Exploratory Data Analysis (EDA) and Visualization**
# ###**Campaign Performance:**

# %% [markdown]
# **➢ Plot a scatter plot to visualize the relationship between Acquisition_Cost and ROI.**

# %%
m_data.columns
# Out:
# Index(['Campaign_ID', 'Company', 'Campaign_Type', 'Target_Audience',
#        'Duration', 'Channel_Used', 'Conversion_Rate', 'Acquisition_Cost',
#        'ROI', 'Location', 'Language', 'Clicks', 'Impressions',
#        'Engagement_Score', 'Customer_Segment', 'Date'],
#       dtype='object')

# %%
plt.figure(figsize=(14,6))
plt.scatter(m_data['Acquisition_Cost'],m_data['ROI'],color='c',edgecolors='b')
plt.title("The Relationship between Acquisition_Cost and ROI")
plt.xlabel('Acquisition_Cost')
plt.ylabel('ROI')
plt.grid(True)
plt.show()

# %% [markdown]
# ###**Interpretation:**
# **Positive Correlation: In this chart show Acquisition_Cost is high ROI is also high. This is Positive Correlation.We can see Majority ROI is below 500.**

# %% [markdown]
# **➢ Create a bar chart to visualize the average Conversion_Rate: for different Channel_Used, categorized by Campaign_Type.**

# %%
avg=m_data['Conversion_Rate'].mean()
avg
# Out:
# np.float64(4.757231966353716)

# %%
g_data=m_data.groupby(['Channel_Used','Campaign_Type'])['Conversion_Rate'].mean().sort_values().reset_index()
g_data
# Out:
#    Channel_Used Campaign_Type  Conversion_Rate
# 0     Instagram  Social Media         4.696410
# 1         Email       Display         4.697857
# 2    Google Ads  Social Media         4.698448
# 3      Facebook  Social Media         4.705616
# 4         Email        Search         4.710543
# 5       Website  Social Media         4.716317
# 6    Google Ads         Email         4.721141
# 7     Instagram    Influencer         4.722847
# 8         Email  Social Media         4.724303
# 9      Facebook        Search         4.731633
# 10      YouTube    Influencer         4.740554
# 11      YouTube       Display         4.747026
# 12    Instagram        Search         4.750821
# 13      YouTube         Email         4.753632
# 14     Facebook         Email         4.754791
# 15        Email    Influencer         4.759144
# 16    Instagram       Display         4.760322
# 17      YouTube        Search         4.760597
# 18      Website        Search         4.761248
# ...

# %%
groupdata=m_data.groupby(['Channel_Used','Campaign_Type'])['Conversion_Rate'].mean()
groupdata
# Out:
# Channel_Used  Campaign_Type
# Email         Display          4.697857
#               Email            4.762608
#               Influencer       4.759144
#               Search           4.710543
#               Social Media     4.724303
# Facebook      Display          4.836175
#               Email            4.754791
#               Influencer       4.868923
#               Search           4.731633
#               Social Media     4.705616
# Google Ads    Display          4.779902
#               Email            4.721141
#               Influencer       4.788560
#               Search           4.762025
#               Social Media     4.698448
# Instagram     Display          4.760322
#               Email            4.855438
#               Influencer       4.722847
#               Search           4.750821
#               Social Media     4.696410
# Website       Display          4.763931
#               Email            4.811886
#               Influencer       4.811400
# ...

# %%
group=m_data.groupby(['Channel_Used','Campaign_Type'])['Conversion_Rate'].mean().reset_index()     # using SNS plot
plt.figure(figsize=(10, 6))

bar1=sns.barplot(data=group, x='Channel_Used', y='Conversion_Rate', hue='Campaign_Type')
for container in bar1.containers:
  bar1.bar_label(container, fmt='%.1f')
plt.title('Avg Conversion Rate by Channel and Campaign Type')
plt.xlabel('Channel Used')
plt.ylabel('Avg Conversion Rate')
plt.legend(title='Campaign Type')
plt.show()

# %%
# using Matplotlib plot
g_data=m_data.groupby(['Channel_Used','Campaign_Type'])['Conversion_Rate'].mean().plot(kind="barh",figsize=(16,8),color="c")
g_data.bar_label(g_data.containers[0])
plt.title("Average Conversion_Rate :for Channel_Used and categorized by Campaign_Type")
plt.xlabel('Avg Conversion_Rate')
plt.ylabel('Channel_Used and categorized by Campaign_Type')
plt.show()

# %% [markdown]
# ###**Interpretation:**
# **Average conversion_rate is below 5 for all channel_used column categorized by Campaign_type.**

# %% [markdown]
# **➢ Visualize the distribution of Engagement_Score across different Campaign_Type using a box plot.**

# %%
# using SNS lot
sns.boxplot(data=m_data,x='Campaign_Type',y='Engagement_Score')
plt.title('The distribution of Engagement_Score across different Campaign_Type')
plt.xlabel('Campaign_Type')
plt.ylabel('Engagement_Score')
plt.show()

# %% [markdown]
# ###**Interpretation:**
#  **In this chart we can see no outliers all campaign_type between 5 to 8 in Engagement_score. social media differ from others.**

# %% [markdown]
# **➢ Analyze the average ROI by Company using a bar chart to compare the profitability of campaigns conducted by different companies.**

# %%
m_data.columns
# Out:
# Index(['Campaign_ID', 'Company', 'Campaign_Type', 'Target_Audience',
#        'Duration', 'Channel_Used', 'Conversion_Rate', 'Acquisition_Cost',
#        'ROI', 'Location', 'Language', 'Clicks', 'Impressions',
#        'Engagement_Score', 'Customer_Segment', 'Date'],
#       dtype='object')

# %%
m_data.head(2)
# Out:
#    Campaign_ID              Company Campaign_Type Target_Audience Duration  \
# 0            1             TechCorp         Email     Women 25-34  30 days
# 1            2  Innovate Industries    Influencer     Women 35-44  45 days
#
#   Channel_Used  Conversion_Rate  Acquisition_Cost    ROI          Location  \
# 0     Facebook         5.294194              9344  62.94           Houston
# 1   Google Ads         3.326375              8783  10.67  Washington, D.C.
#
#   Language  Clicks  Impressions  Engagement_Score  Customer_Segment  \
# 0  English    3045        67836                 5  Tech Enthusiasts
# 1   German    1944        66361                 4           Foodies
#
#          Date
# 0  01-01-2023
# 1  01-01-2023

# %%
m_data['Company'].nunique()
# Out:
# 5

# %%
avgroi=m_data.groupby('Company')['ROI'].mean().sort_values()
avgroi
# Out:
# Company
# TechCorp               178.355158
# Data Tech Solutions    179.493878
# Innovate Industries    181.513559
# NexGen Systems         187.216772
# Alpha Innovations      187.802897
# Name: ROI, dtype: float64

# %%
# Using Matplotlib plot
bars=m_data.groupby('Company')['ROI'].mean().sort_values().plot(kind="bar",figsize=(8,4),color="c")
bars.bar_label(bars.containers[0])
plt.title('ROI by Company')
plt.xlabel('Company')
plt.ylabel('ROI')
plt.show()

# %% [markdown]
# ###**Interpretation:**
# **In this Chart we can see the average ROI for all Company above 178 to 187.Alpha Innovations is the highest ROI.**

# %% [markdown]
# **➢ Examine the correlation between Engagement_Score and Conversion_Rate using a heatmap.**

# %%
corr_data=m_data[['Engagement_Score','Conversion_Rate']]
corr_matrix=corr_data.corr()
corr_matrix
# Out:
#                   Engagement_Score  Conversion_Rate
# Engagement_Score          1.000000         0.010546
# Conversion_Rate           0.010546         1.000000

# %%
target_corr=corr_matrix[['Engagement_Score','Conversion_Rate']]
target_corr
# Out:
#                   Engagement_Score  Conversion_Rate
# Engagement_Score          1.000000         0.010546
# Conversion_Rate           0.010546         1.000000

# %%
# using SNS plot
plt.figure(figsize=(6,4))
sns.heatmap(corr_matrix,annot=True,cmap='coolwarm')
plt.title("correlation between Engagement_Score and Conversion_Rate")
plt.show()

# %% [markdown]
# ###**Interpretation:**
# **In this chart we can see Engagement_Score  column has a lower correlation with Conversion_Rate (0.011).**
# **This is very close to 0 , 0-Means there is almost no relationship between these two variables.**

# %% [markdown]
# ###**Customer Segmentation:**
# **➢ Create a count plot to visualize the distribution of Target_Audience.**

# %%
m_data.groupby('Target_Audience')['Target_Audience'].value_counts().sort_values()
# Out:
# Target_Audience
# Men 18-24      2856
# All Ages       3717
# Women 35-44    3929
# Men 25-34      5412
# Women 25-34    6115
# Name: count, dtype: int64

# %%
# Using SNS plot
plt.figure(figsize=(8, 5))
count1=sns.countplot(data=m_data, x='Target_Audience',order=m_data['Target_Audience'].value_counts().sort_values().index)
for container in count1.containers:
  count1.bar_label(container,fmt='%.2f')
plt.title('Distribution of Target Audience')
plt.xlabel('Target Audience')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(8, 5))
count1 = sns.countplot( data=m_data, x='Target_Audience', palette='Set2', order=m_data['Target_Audience'].value_counts().sort_values().index)
for container in count1.containers:
    count1.bar_label(container, fmt='%d')   # d -integer values
plt.title('Distribution of Target Audience')
plt.xlabel('Target Audience')
plt.ylabel('Count')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-349-4135619257.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   count1 = sns.countplot( data=m_data, x='Target_Audience', palette='Set2', order=m_data['Target_Audience'].value_counts().sort_values().index)

# %%
# using matplotlib plot
counts=m_data.groupby('Target_Audience')['Target_Audience'].value_counts().sort_values().plot(kind="bar",figsize=(8,4),color="c")
counts.bar_label(counts.containers[0])
plt.title('Distribution of Target Audience')
plt.xlabel('Target Audience')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ###**Interpretation:**
# **In this chart we can see the count of target Audience lowest count is Men 18-24 and highest count is women 25-34.**

# %% [markdown]
# **➢ Identify which Customer_Segment has the highest Conversion_Rate for each Language using a bar chart.**

# %%
m_data.groupby(['Language','Customer_Segment'])['Conversion_Rate'].max()
# Out:
# Language  Customer_Segment
# English   Fashionistas           5.991730
#           Foodies                5.991956
#           Health & Wellness      5.994573
#           Outdoor Adventurers    5.990216
#           Tech Enthusiasts       5.996693
# French    Fashionistas           7.464671
#           Foodies                7.339280
#           Health & Wellness      7.455621
#           Outdoor Adventurers    7.438360
#           Tech Enthusiasts       7.372500
# German    Fashionistas           7.465793
#           Foodies                7.273576
#           Health & Wellness      7.462054
#           Outdoor Adventurers    7.405942
#           Tech Enthusiasts       7.353365
# Mandarin  Fashionistas           7.375653
#           Foodies                7.256409
#           Health & Wellness      7.268547
#           Outdoor Adventurers    7.436307
#           Tech Enthusiasts       7.429612
# Spanish   Fashionistas           7.465279
#           Foodies                7.418547
# ...

# %%
m_data.groupby(['Customer_Segment','Language'])['Conversion_Rate'].max()
# Out:
# Customer_Segment     Language
# Fashionistas         English     5.991730
#                      French      7.464671
#                      German      7.465793
#                      Mandarin    7.375653
#                      Spanish     7.465279
# Foodies              English     5.991956
#                      French      7.339280
#                      German      7.273576
#                      Mandarin    7.256409
#                      Spanish     7.418547
# Health & Wellness    English     5.994573
#                      French      7.455621
#                      German      7.462054
#                      Mandarin    7.268547
#                      Spanish     7.402762
# Outdoor Adventurers  English     5.990216
#                      French      7.438360
#                      German      7.405942
#                      Mandarin    7.436307
#                      Spanish     7.469907
# Tech Enthusiasts     English     5.996693
#                      French      7.372500
# ...

# %%
# using matplotlib plot
high=m_data.groupby(['Language','Customer_Segment'])['Conversion_Rate'].max().plot(kind="barh",figsize=(10,6),color="b")
high.bar_label(high.containers[0])
plt.title('Customer_Segment has the highest Conversion_Rate for each Language')
plt.ylabel('Customer_Segment and Language')
plt.xlabel('Conversion_Rate')
plt.show()

# %%
m_data['Customer_Segment'].nunique()
# Out:
# 5

# %%
m_data['Language'].nunique()
# Out:
# 5

# %%
# Using SNS plot
agg_data = m_data.groupby(['Language', 'Customer_Segment'])['Conversion_Rate'].max().reset_index()
plt.figure(figsize=(10, 6))
bar2=sns.barplot(data=agg_data, x='Language', y='Conversion_Rate', hue='Customer_Segment')
for container in bar2.containers:
  bar2.bar_label(container,fmt='%.1f')
plt.title('Highest Customer_Segment has the highest Conversion_Rate for each Language')
plt.xlabel('Language and  Customer_Segment  ')
plt.ylabel('highest Conversion_Rate')
plt.legend(title='Customer_Segment')
plt.show()

# %% [markdown]
# ###**Interpretation:**
# **In this chart we can see highest conversion_rate language is spanish and similar in French , lowest rate language is english.**

# %% [markdown]
# **➢ Visualize the distribution of Acquisition_Cost across each Customer_Segment, categorized by Channel_Used, using a box plot.**

# %%
# Using SNS plot
plt.figure(figsize=(10, 6))
sns.boxplot(data=m_data, x='Customer_Segment', y='Acquisition_Cost', hue='Channel_Used')
plt.title(' Distribution of Acquisition_Cost across each Customer_Segment, categorized by Channel_Used')
plt.xlabel('Customer_Segment')
plt.ylabel('Acquisition_Cost')
plt.legend(title='Channel_Used',loc='upper right')
plt.show()

# %% [markdown]
# ###**Interpretation:**
# **In this chart we can see all Acquisition_Cost Distribution of across each Customer_Segment, categorized by Channel_Used is between 3500 to 8000.**

# %%
# Using matplotlib plot
barsh = m_data.groupby(['Customer_Segment', 'Channel_Used'])['Acquisition_Cost'].mean().plot(kind='barh',color='skyblue',figsize=(12, 8))
barsh.bar_label(barsh.containers[0])
plt.title(' Distribution of Acquisition_Cost across each Customer_Segment, categorized by Channel_Used')
plt.ylabel('Customer_Segment and Channel_Used')
plt.xlabel('Acquisition_Cost')
plt.show()

# %% [markdown]
# ###**Interpretaion:**
# **In this chart we can see average of distribution above 5000 for all customer_segment and channel_used.**

# %% [markdown]
# **➢ Analyze average Conversion_Rate by Language using a bar chart to compare the effectiveness of campaigns conducted in different languages.**

# %%
m_data.columns
# Out:
# Index(['Campaign_ID', 'Company', 'Campaign_Type', 'Target_Audience',
#        'Duration', 'Channel_Used', 'Conversion_Rate', 'Acquisition_Cost',
#        'ROI', 'Location', 'Language', 'Clicks', 'Impressions',
#        'Engagement_Score', 'Customer_Segment', 'Date'],
#       dtype='object')

# %%
avgcon = m_data.groupby(['Language', 'Campaign_Type'])['Conversion_Rate'].mean()
avgcon
# Out:
# Language  Campaign_Type
# English   Display          5.005857
#           Email            5.009501
#           Influencer       5.017726
#           Search           5.003263
#           Social Media     4.989449
# French    Display          4.616247
#           Email            4.686976
#           Influencer       4.658384
#           Search           4.692292
#           Social Media     4.583326
# German    Display          4.682890
#           Email            4.693059
#           Influencer       4.688149
#           Search           4.614105
#           Social Media     4.561744
# Mandarin  Display          4.727731
#           Email            4.738097
#           Influencer       4.671916
#           Search           4.706155
#           Social Media     4.657573
# Spanish   Display          4.626330
#           Email            4.632326
#           Influencer       4.691297
#           Search           4.583311
#           Social Media     4.619666
# ...

# %%
# Using SNS plot
avgcon = m_data.groupby(['Language', 'Campaign_Type'])['Conversion_Rate'].mean().reset_index()
plt.figure(figsize=(10, 6))
bar_plot = sns.barplot(data=avgcon, x='Language', y='Conversion_Rate', hue='Campaign_Type')
for container in bar_plot.containers:
    bar_plot.bar_label(container, fmt='%.2f')
plt.title('Average Conversion Rate by Language and Campaign Type')
plt.ylabel('Average Conversion Rate')
plt.xlabel('Language')
plt.legend(title='Campaign Type')
plt.tight_layout()
plt.show()

# %%
# Using matplotlib plot
bars1 = m_data.groupby(['Language', 'Campaign_Type'])['Conversion_Rate'].mean().plot(kind='barh',color='skyblue',figsize=(12, 8))
bars1.bar_label(bars1.containers[0])
plt.title(' Average Conversion_Rate to compare the campaigns in different languages')
plt.ylabel('Language and Campaign_Type')
plt.xlabel('Conversion_Rate')
plt.show()

# %%
# Using matplotlib plot
bars_data = m_data.groupby(['Language'])['Conversion_Rate'].mean().plot(kind='bar',color='skyblue',figsize=(12, 8))
bars_data.bar_label(bars_data.containers[0])
plt.title(' Average Conversion_Rate to compare the different languages')
plt.xlabel('Language')
plt.ylabel('Conversion_Rate')
plt.show()

# %% [markdown]
# ###**Interpretation:**
# **In this chart we can see average distribution of Conversion_Rate.All average distribution of Conversion_Rate is above 4.5 to 5.**

# %% [markdown]
# ###**Channel Effectiveness:**
# **➢ Compare the Engagement_Score for different Channels_Used, segmented by Campaign_Type, using a bar chart.**

# %%
# Using SNS plot
plt.figure(figsize=(10, 6))
barsh3= sns.barplot(data=m_data, x='Channel_Used', y='Engagement_Score', hue='Campaign_Type')
for container in barsh3.containers:
    barsh3.bar_label(container, fmt='%.1f')
plt.title('Compare the Engagement_Score for different Channels_Used, segmented by Campaign_Type')
plt.ylabel('Engagement_Score')
plt.xlabel('Channel_Used')
plt.legend(title='Campaign Type',loc='lower center')
plt.tight_layout()
plt.show()

# %% [markdown]
# ###**Interpretation:**
# **In this chart we can see Compare the Engagement_Score for different Channels_Used, segmented by Campaign_Type. The score is above 6.5 to below 7.**

# %% [markdown]
# **➢ Show the distribution of total ROI across different Channels_Used using a pie chart.**

# %%
total_roi = m_data.groupby('Channel_Used')['ROI'].sum()
total_roi
# Out:
# Channel_Used
# Email         673804.39
# Facebook      704684.82
# Google Ads    678232.24
# Instagram     646462.11
# Website       664577.42
# YouTube       660542.33
# Name: ROI, dtype: float64

# %%
# Using matplotlib plot
total_roi = m_data.groupby('Channel_Used')['ROI'].sum()
plt.figure(figsize=(8, 8))
total_roi.plot(kind='pie',autopct='%1.1f%%')
plt.title('Distribution of Total ROI by Channel Used')
plt.ylabel('')
plt.show()

# %% [markdown]
# ###**Interpretation:**
# **In this chart we can see Distribution of Total ROI by Channel Used. All Channel Used is above 16% of distribution.Highest distribution Facebook,Lowest is Instagram.**

# %%
# Using Matplotlib plot
m_data.groupby('Channel_Used')['ROI'].sum().plot(kind='pie',autopct='%1.0f%%')
plt.title('Distribution of Total ROI by Channel Used')
plt.ylabel('')    # Hide y Label
plt.show()

# %% [markdown]
# ###**Interpretation:**
# **In this chart to round down(round floor) the values.**

# %% [markdown]
# **➢ Plot a scatter plot to show the relationship between Clicks and Impressions for each Channel_Used.**

# %%
m_data.columns
# Out:
# Index(['Campaign_ID', 'Company', 'Campaign_Type', 'Target_Audience',
#        'Duration', 'Channel_Used', 'Conversion_Rate', 'Acquisition_Cost',
#        'ROI', 'Location', 'Language', 'Clicks', 'Impressions',
#        'Engagement_Score', 'Customer_Segment', 'Date'],
#       dtype='object')

# %%
# Using SNS plot
plt.figure(figsize=(8, 6))
sns.scatterplot(data=m_data, x='Impressions', y='Clicks', hue='Channel_Used',palette='Set2')
plt.title('Clicks vs Impressions by Channel Used')
plt.xlabel('Impressions')
plt.ylabel('Clicks')
plt.grid(True)
plt.show()

# %% [markdown]
# ###**Interprettaation:**
# **In this chart we can see the relationship between Clicks and Impressions for each Channel_Used.positive correlation Impressions increase, Clicks also increase.All channel to perform efficiently.**

# %% [markdown]
# ###**Time-Based Analysis:**
# **➢ Plot the distribution of Duration using a histogram.**

# %%
# Using Matplotlib plot
plt.hist(m_data['Duration'].sort_values(), bins=10, color='c', edgecolor='black')
plt.xlabel('Duration')
plt.ylabel('count')
plt.title('Distribution of Duration')
plt.show()

# %%
# Using SNS plot
duration_sorted = m_data['Duration'].sort_values()
hist1=sns.histplot(duration_sorted, bins=10, color='blue')
for container in hist1.containers:
  hist1.bar_label(container)
plt.xlabel('Duration')
plt.ylabel('count')
plt.title('Distribution of Duration')
plt.show()

# %% [markdown]
# ###**Interpretation:**
# **In this chart we can see Distribution of Duration.In duration 30 days is the highest count of distribution.And duration 60 days is the lowest count of distribution.**

# %% [markdown]
# **➢ Analyze how the overall Conversion_Rate has changed over Date for each Company using a line chart.**

# %%
m_data.columns
# Out:
# Index(['Campaign_ID', 'Company', 'Campaign_Type', 'Target_Audience',
#        'Duration', 'Channel_Used', 'Conversion_Rate', 'Acquisition_Cost',
#        'ROI', 'Location', 'Language', 'Clicks', 'Impressions',
#        'Engagement_Score', 'Customer_Segment', 'Date'],
#       dtype='object')

# %%
# Using matplotlib plot
lines=m_data.groupby(['Date','Company'])['Conversion_Rate'].mean().plot(kind='line',color='skyblue',figsize=(12, 8),marker='o')
plt.title("Conversion Rate Over Time by Company")
plt.xlabel("Date for each Company")
plt.ylabel("Conversion_Rate")
plt.grid(True)
plt.show()

# %%
# Using SNS plot
plt.figure(figsize=(12,8))
sns.lineplot(data=m_data, x='Date', y='Conversion_Rate', hue='Company', marker='o')
plt.title('Conversion Rate Over Date by Company')
plt.xlabel('Date')
plt.ylabel(' Conversion Rate')
plt.grid(True)
plt.legend(title='Company')
plt.show()

# %% [markdown]
# ###**Interpretation:**
# **In this chart we can see average conversion rate across the company and date.you can see the ine is increasing and decreasing not stable. High conversion rate show high performance in company.**

# %% [markdown]
# **➢ Examine the trend of Engagement_Score over Date with a line chart.**

# %%
# Using SNS plot
plt.figure(figsize=(10,6))
sns.lineplot(data=m_data, x='Date', y='Engagement_Score',marker='o', color='green')
plt.title('The trend of Engagement_Score over Date ')
plt.xlabel('Date')
plt.ylabel('Engagement_Score')
plt.grid(True)
plt.show()

# %%
# Using matplotlib plot
engagement_trend = m_data.groupby('Date')['Engagement_Score'].mean().reset_index()
plt.figure(figsize=(8, 5))
plt.plot(engagement_trend['Date'], engagement_trend['Engagement_Score'], marker='o', color='green')
plt.title('Trend of Engagement Score Over Date')
plt.xlabel('Date')
plt.ylabel('Average Engagement Score')
plt.grid(True)
plt.show()

# %% [markdown]
# ###**Interpretation:**
# **In this chart we can see the trend of Engagement Score Over Date.to distribute engagement score between 4.5 to 8.5.**

# %% [markdown]
# ###**Geographic Analysis:**
# **➢ Determine which location has the highest Acquisition_Cost using a bar chart.**

# %%
m_data['Location'].nunique()
# Out:
# 10

# %%
# Using SNS plot
highcost = m_data.groupby(['Location'])['Acquisition_Cost'].max().sort_values().reset_index()
plt.figure(figsize=(10,6))
barshplot=sns.barplot(data=highcost, x='Location', y='Acquisition_Cost',color='b')
for container in barshplot.containers:
  barshplot.bar_label(container,fmt='%.1f')
plt.title('Highest Acquisition Cost by Location')
plt.xlabel('Location')
plt.ylabel('Acquisition_Cost')
plt.show()

# %%
# Using matplotlib plot
loc_high = m_data.groupby('Location')['Acquisition_Cost'].max().sort_values().plot(kind='bar',color='skyblue',figsize=(8, 6))
loc_high.bar_label(loc_high.containers[0])
plt.title('Highest Acquisition Cost by Location')
plt.xlabel('Location')
plt.ylabel('Acquisition Cost')
plt.show()

# %% [markdown]
# ###**Interpretation:**
# **In this chart we can see Highest Acquisition Cost by Location all location above 9986 is the max value.highest max value is 9998.**

# %% [markdown]
# **➢ Visualize the Conversion_Rate by different Location, categorized by Target_Audience, using a bar chart.**

# %%
# Using SNS plot
plt.figure(figsize=(12, 6))
diffbar= sns.barplot(data=m_data, x='Target_Audience', y='Conversion_Rate',hue='Location')
for container in diffbar.containers:
    diffbar.bar_label(container, fmt='%.1f')
plt.title('Categorized by Target_Audience and different Location by Conversion_Rate')
plt.ylabel('Conversion_Rate')
plt.xlabel('Target_Audience')
plt.legend(title='Location',loc='lower center')
plt.tight_layout()
plt.show()

# %%
# Using matplotlib plot
g2= m_data.groupby(['Target_Audience', 'Location'])['Conversion_Rate'].mean().plot(kind='barh',color='skyblue',figsize=(14, 10))
g2.bar_label(g2.containers[0])
plt.title('Conversion Rate by Location and Target Audience')
plt.ylabel('Target Audience and Location')
plt.xlabel('Average Conversion Rate')
plt.show()

# %% [markdown]
# ###**Interpretation:**
# **In this chart we can see distribution of Conversion_Rate by different Location, categorized by Target_Audience.All average conversion rate is above 4.5.**

# %% [markdown]
# **➢ Illustrate the proportion of ROI by Location using a pie chart.**

# %%
# Using matplotlib plot
proportion_roi = m_data.groupby('Location')['ROI'].sum()
plt.figure(figsize=(8, 8))
proportion_roi.plot(kind='pie',autopct='%1.1f%%')
plt.title('The proportion of ROI by Location')
plt.ylabel('')
plt.show()

# %% [markdown]
# ###**Interpretation:**
# **In this chart we can see  the proportion of ROI by Location.All location distribute above 9.3% ,max percentage location is chicago.**
